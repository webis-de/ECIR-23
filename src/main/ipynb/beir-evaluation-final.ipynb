# %%
import pandas as pd
import sys
sys.path.append('../python')
from evaluation_util import evaluate_on_original_pool_only
from trectools import TrecQrel, TrecRun, TrecEval
from tqdm import tqdm
from cross_validation_util import cross_validation_experiment
from statistics import mean
from parametrized_bootstrapping_model import BootstrappingBySelectingMostLikelyDataPoint, FixedQuantileBootstrappingModel

def qrels_dict(f):
    ret = {}
    for _, l in tqdm(pd.read_csv(f, sep='\t').iterrows()):
        internal_id = (int(l['query_id']), l['doc_id'])
        if internal_id in ret:
            print(f'Duplicate {internal_id}')
            #raise ValueError('Can not happen')

        ret[internal_id] = int(l['score'])
    return ret

def load_qrels(with_additional=False):
    orig_qrels_dict = qrels_dict('../resources/beir/trec-covid-beir/qrels/test.tsv')
    add_qrels_dict = qrels_dict('../resources/unprocessed/topics-and-qrels/qrels.trec-covid-additional-judgments.tsv')
    
    df_ret = []
    for (qid, doc_id), score in orig_qrels_dict.items():
        if (qid, doc_id) in add_qrels_dict:
            continue
        
        df_ret += [{"query": str(qid),"q0": "0","docid": doc_id,"rel": score}]

    if with_additional:
        for (qid, doc_id), score in add_qrels_dict.items():
            df_ret += [{"query": str(qid),"q0": "Q0","docid": doc_id,"rel": score}]
    
    df_ret = pd.DataFrame(df_ret)
    
    ret = TrecQrel()
    ret.qrels_data = df_ret
    
    return ret

qrels_complete = TrecQrel('beir-evaluation-data/complete-annotation-trec-covid.txt')
qrels_with_unjudged = TrecQrel('beir-evaluation-data/incomplete-beir-trec-covid.txt')

print(len(qrels_with_unjudged.qrels_data))
print(len(qrels_complete.qrels_data))
# Out:
# 66334
# 67314

# %%
# !mkdir beir-evaluation-data/runs/

# %%
# !cp ../resources/processed/normalized-runs/trec-system-runs/trec-covid/tas-b-09-01-2023-run.txt  beir-evaluation-data/runs/

# %%
runs = !ls beir-evaluation-data/runs/
runs = [i.split('-run.txt')[0] for i in runs]
runs = {i: TrecRun(f'beir-evaluation-data/runs/{i}-run.txt') for i in tqdm(runs)}

def eval_run(run_name, run):
    return {
        'system': run_name,
        'unjudged@10 (incomplete)': TrecEval(run, qrels_with_unjudged).get_unjudged(depth=10),
        'ndcg@10 (incomplete)': TrecEval(run, qrels_with_unjudged).get_ndcg(depth=10),
        'ndcg@10 (incomplete, removeUnjudged)': TrecEval(run, qrels_with_unjudged).get_ndcg(depth=10, removeUnjudged=True),
        'unjudged@10 (complete)': TrecEval(run, qrels_complete).get_unjudged(depth=10),
        'ndcg@10 (complete)': TrecEval(run, qrels_complete).get_ndcg(depth=10),
    }
    
df_eval = []
for run_name, run in tqdm(runs.items()):
    df_eval += [eval_run(run_name, run)]

df_eval = pd.DataFrame(df_eval)
df_eval
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#  25%|██▌       | 1/4 [00:00<00:00,  6.12it/s]
# 100%|██████████| 4/4 [00:00<00:00, 12.34it/s]
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#  25%|██▌       | 1/4 [00:00<00:00,  3.04it/s]
#  50%|█████     | 2/4 [00:00<00:00,  3.88it/s]
#  75%|███████▌  | 3/4 [00:00<00:00,  4.51it/s]
# 100%|██████████| 4/4 [00:00<00:00,  4.04it/s]
#                        system  unjudged@10 (incomplete)  ndcg@10 (incomplete)  \
# 0             ance-09-01-2023                     0.224              0.652447
# 1                  BBGhelani2                     0.000              0.678996
# 2  colbert-ranking-26-12-2022                     0.172              0.679529
# 3            tas-b-09-01-2023                     0.410              0.481254
#
#    ndcg@10 (incomplete, removeUnjudged)  unjudged@10 (complete)  \
# 0                              0.772475                   0.002
# 1                              0.678996                   0.000
# 2                              0.769887                   0.016
# 3                              0.704533                   0.000
#
#    ndcg@10 (complete)
# 0            0.734673
# 1            0.678996
# 2            0.733639
# 3            0.555436

# %%
df_eval.sort_values('ndcg@10 (incomplete)', ascending=False).reset_index()
# Out:
#    index                      system  unjudged@10 (incomplete)  \
# 0      2  colbert-ranking-26-12-2022                     0.172
# 1      1                  BBGhelani2                     0.000
# 2      0             ance-09-01-2023                     0.224
# 3      3            tas-b-09-01-2023                     0.410
#
#    ndcg@10 (incomplete)  ndcg@10 (incomplete, removeUnjudged)  \
# 0              0.679529                              0.769887
# 1              0.678996                              0.678996
# 2              0.652447                              0.772475
# 3              0.481254                              0.704533
#
#    unjudged@10 (complete)  ndcg@10 (complete)
# 0                   0.016            0.733639
# 1                   0.000            0.678996
# 2                   0.002            0.734673
# 3                   0.000            0.555436

# %%
ret = []

for measure in ['residual-ndcg@10', 'bs-run-and-pool-dependent-1000-ndcg@10']:
    for system in ['colbert-ranking-26-12-2022', 'ance-09-01-2023', 'tas-b-09-01-2023']:
        ret += [evaluate_on_original_pool_only(
            run_file=f'beir-evaluation-data/runs/{system}-run.txt', 
            qrel_file='beir-evaluation-data/incomplete-beir-trec-covid.txt', 
            measure=measure
        )]
# Out:
# Bootstrapping:   0%|          | 0/50 [00:00<?, ?it/s]
# Bootstrapping:   2%|▏         | 1/50 [00:09<07:50,  9.60s/it]
# Bootstrapping:   4%|▍         | 2/50 [00:18<07:17,  9.12s/it]
# Bootstrapping:   6%|▌         | 3/50 [00:27<07:15,  9.26s/it]
# Bootstrapping:   8%|▊         | 4/50 [00:36<06:59,  9.12s/it]
# Bootstrapping:  10%|█         | 5/50 [00:47<07:12,  9.61s/it]
# Bootstrapping:  12%|█▏        | 6/50 [00:56<06:55,  9.44s/it]
# Bootstrapping:  14%|█▍        | 7/50 [01:04<06:24,  8.95s/it]
# Bootstrapping:  16%|█▌        | 8/50 [01:12<06:01,  8.60s/it]
# Bootstrapping:  18%|█▊        | 9/50 [01:19<05:41,  8.32s/it]
# Bootstrapping:  20%|██        | 10/50 [01:27<05:25,  8.15s/it]
# Bootstrapping:  22%|██▏       | 11/50 [01:35<05:11,  7.99s/it]
# Bootstrapping:  24%|██▍       | 12/50 [01:42<05:00,  7.90s/it]
# Bootstrapping:  26%|██▌       | 13/50 [01:51<04:59,  8.11s/it]
# Bootstrapping:  28%|██▊       | 14/50 [02:00<04:59,  8.33s/it]
# Bootstrapping:  30%|███       | 15/50 [02:09<04:55,  8.43s/it]
# Bootstrapping:  32%|███▏      | 16/50 [02:18<04:59,  8.82s/it]
# Bootstrapping:  34%|███▍      | 17/50 [02:27<04:51,  8.82s/it]
# Bootstrapping:  36%|███▌      | 18/50 [02:37<04:49,  9.05s/it]
# Bootstrapping:  38%|███▊      | 19/50 [02:46<04:39,  9.03s/it]
# Bootstrapping:  40%|████      | 20/50 [02:55<04:30,  9.02s/it]
# Bootstrapping:  42%|████▏     | 21/50 [03:05<04:36,  9.54s/it]
# Bootstrapping:  44%|████▍     | 22/50 [03:15<04:26,  9.50s/it]
# Bootstrapping:  46%|████▌     | 23/50 [03:24<04:16,  9.48s/it]
# Bootstrapping:  48%|████▊     | 24/50 [03:36<04:23, 10.12s/it]
# Bootstrapping:  50%|█████     | 25/50 [03:46<04:12, 10.11s/it]
# Bootstrapping:  52%|█████▏    | 26/50 [03:56<04:02, 10.09s/it]
# Bootstrapping:  54%|█████▍    | 27/50 [04:06<03:54, 10.21s/it]
# Bootstrapping:  56%|█████▌    | 28/50 [04:15<03:34,  9.77s/it]
# Bootstrapping:  58%|█████▊    | 29/50 [04:23<03:15,  9.33s/it]
# Bootstrapping:  60%|██████    | 30/50 [04:32<03:03,  9.19s/it]
# Bootstrapping:  62%|██████▏   | 31/50 [04:42<02:55,  9.24s/it]
# Bootstrapping:  64%|██████▍   | 32/50 [04:52<02:52,  9.60s/it]
# Bootstrapping:  66%|██████▌   | 33/50 [05:02<02:46,  9.80s/it]
# Bootstrapping:  68%|██████▊   | 34/50 [05:13<02:40, 10.03s/it]
# Bootstrapping:  70%|███████   | 35/50 [05:23<02:29,  9.94s/it]
# Bootstrapping:  72%|███████▏  | 36/50 [05:34<02:26, 10.46s/it]
# Bootstrapping:  74%|███████▍  | 37/50 [05:44<02:14, 10.32s/it]
# Bootstrapping:  76%|███████▌  | 38/50 [05:56<02:09, 10.79s/it]
# Bootstrapping:  78%|███████▊  | 39/50 [06:09<02:04, 11.30s/it]
# Bootstrapping:  80%|████████  | 40/50 [06:20<01:51, 11.19s/it]
# Bootstrapping:  82%|████████▏ | 41/50 [06:31<01:41, 11.24s/it]
# Bootstrapping:  84%|████████▍ | 42/50 [06:43<01:31, 11.40s/it]
# Bootstrapping:  86%|████████▌ | 43/50 [06:54<01:18, 11.28s/it]
# Bootstrapping:  88%|████████▊ | 44/50 [07:04<01:05, 10.88s/it]
# Bootstrapping:  90%|█████████ | 45/50 [07:13<00:52, 10.43s/it]
# Bootstrapping:  92%|█████████▏| 46/50 [07:21<00:38,  9.74s/it]
# Bootstrapping:  94%|█████████▍| 47/50 [07:29<00:27,  9.27s/it]
# Bootstrapping:  96%|█████████▌| 48/50 [07:37<00:17,  8.89s/it]
# Bootstrapping:  98%|█████████▊| 49/50 [07:46<00:08,  8.67s/it]
# Bootstrapping: 100%|██████████| 50/50 [07:55<00:00,  9.50s/it]
#
# Bootstrapping:   0%|          | 0/50 [00:00<?, ?it/s]
# Bootstrapping:   2%|▏         | 1/50 [00:10<08:28, 10.38s/it]
# Bootstrapping:   4%|▍         | 2/50 [00:20<08:24, 10.50s/it]
# Bootstrapping:   6%|▌         | 3/50 [00:30<07:50, 10.02s/it]
# Bootstrapping:   8%|▊         | 4/50 [00:38<07:04,  9.23s/it]
# Bootstrapping:  10%|█         | 5/50 [00:46<06:39,  8.89s/it]
# Bootstrapping:  12%|█▏        | 6/50 [00:54<06:16,  8.56s/it]
# Bootstrapping:  14%|█▍        | 7/50 [01:03<06:06,  8.52s/it]
# Bootstrapping:  16%|█▌        | 8/50 [01:11<05:50,  8.36s/it]
# Bootstrapping:  18%|█▊        | 9/50 [01:19<05:45,  8.43s/it]
# Bootstrapping:  20%|██        | 10/50 [01:28<05:39,  8.49s/it]
# Bootstrapping:  22%|██▏       | 11/50 [01:37<05:37,  8.65s/it]
# Bootstrapping:  24%|██▍       | 12/50 [01:46<05:31,  8.74s/it]
# Bootstrapping:  26%|██▌       | 13/50 [01:54<05:17,  8.57s/it]
# Bootstrapping:  28%|██▊       | 14/50 [02:03<05:19,  8.86s/it]
# Bootstrapping:  30%|███       | 15/50 [02:13<05:15,  9.03s/it]
# Bootstrapping:  32%|███▏      | 16/50 [02:23<05:22,  9.48s/it]
# Bootstrapping:  34%|███▍      | 17/50 [02:33<05:18,  9.64s/it]
# Bootstrapping:  36%|███▌      | 18/50 [02:43<05:10,  9.70s/it]
# Bootstrapping:  38%|███▊      | 19/50 [02:53<04:56,  9.56s/it]
# Bootstrapping:  40%|████      | 20/50 [03:01<04:39,  9.33s/it]
# Bootstrapping:  42%|████▏     | 21/50 [03:10<04:24,  9.13s/it]
# Bootstrapping:  44%|████▍     | 22/50 [03:21<04:31,  9.69s/it]
# Bootstrapping:  46%|████▌     | 23/50 [03:34<04:45, 10.59s/it]
# Bootstrapping:  48%|████▊     | 24/50 [03:43<04:28, 10.34s/it]
# Bootstrapping:  50%|█████     | 25/50 [03:54<04:18, 10.34s/it]
# Bootstrapping:  52%|█████▏    | 26/50 [04:04<04:09, 10.38s/it]
# Bootstrapping:  54%|█████▍    | 27/50 [04:15<03:59, 10.43s/it]
# Bootstrapping:  56%|█████▌    | 28/50 [04:25<03:46, 10.31s/it]
# Bootstrapping:  58%|█████▊    | 29/50 [04:34<03:32, 10.10s/it]
# Bootstrapping:  60%|██████    | 30/50 [04:44<03:20, 10.05s/it]
# Bootstrapping:  62%|██████▏   | 31/50 [04:53<03:02,  9.58s/it]
# Bootstrapping:  64%|██████▍   | 32/50 [05:01<02:45,  9.22s/it]
# Bootstrapping:  66%|██████▌   | 33/50 [05:10<02:32,  8.98s/it]
# Bootstrapping:  68%|██████▊   | 34/50 [05:19<02:23,  8.99s/it]
# Bootstrapping:  70%|███████   | 35/50 [05:27<02:13,  8.88s/it]
# Bootstrapping:  72%|███████▏  | 36/50 [05:36<02:03,  8.83s/it]
# Bootstrapping:  74%|███████▍  | 37/50 [05:45<01:54,  8.77s/it]
# Bootstrapping:  76%|███████▌  | 38/50 [05:53<01:42,  8.55s/it]
# Bootstrapping:  78%|███████▊  | 39/50 [06:02<01:35,  8.69s/it]
# Bootstrapping:  80%|████████  | 40/50 [06:13<01:34,  9.41s/it]
# Bootstrapping:  82%|████████▏ | 41/50 [06:22<01:25,  9.47s/it]
# Bootstrapping:  84%|████████▍ | 42/50 [06:31<01:13,  9.24s/it]
# Bootstrapping:  86%|████████▌ | 43/50 [06:39<01:01,  8.77s/it]
# Bootstrapping:  88%|████████▊ | 44/50 [06:47<00:52,  8.72s/it]
# Bootstrapping:  90%|█████████ | 45/50 [06:57<00:44,  8.90s/it]
# Bootstrapping:  92%|█████████▏| 46/50 [07:06<00:36,  9.07s/it]
# Bootstrapping:  94%|█████████▍| 47/50 [07:16<00:27,  9.26s/it]
# Bootstrapping:  96%|█████████▌| 48/50 [07:25<00:18,  9.31s/it]
# Bootstrapping:  98%|█████████▊| 49/50 [07:35<00:09,  9.39s/it]
# Bootstrapping: 100%|██████████| 50/50 [07:45<00:00,  9.30s/it]
#
# Bootstrapping:   0%|          | 0/50 [00:00<?, ?it/s]
# Bootstrapping:   2%|▏         | 1/50 [00:09<07:27,  9.14s/it]
# Bootstrapping:   4%|▍         | 2/50 [00:18<07:21,  9.20s/it]
# Bootstrapping:   6%|▌         | 3/50 [00:29<07:51, 10.03s/it]
# Bootstrapping:   8%|▊         | 4/50 [00:39<07:41, 10.04s/it]
# Bootstrapping:  10%|█         | 5/50 [00:48<07:19,  9.76s/it]
# Bootstrapping:  12%|█▏        | 6/50 [00:56<06:45,  9.22s/it]
# Bootstrapping:  14%|█▍        | 7/50 [01:05<06:25,  8.97s/it]
# Bootstrapping:  16%|█▌        | 8/50 [01:14<06:17,  9.00s/it]
# Bootstrapping:  18%|█▊        | 9/50 [01:25<06:39,  9.73s/it]
# Bootstrapping:  20%|██        | 10/50 [01:35<06:33,  9.84s/it]
# Bootstrapping:  22%|██▏       | 11/50 [01:45<06:27,  9.93s/it]
# Bootstrapping:  24%|██▍       | 12/50 [01:58<06:45, 10.66s/it]
# Bootstrapping:  26%|██▌       | 13/50 [02:10<06:47, 11.02s/it]
# Bootstrapping:  28%|██▊       | 14/50 [02:18<06:12, 10.36s/it]
# Bootstrapping:  30%|███       | 15/50 [02:27<05:42,  9.78s/it]
# Bootstrapping:  32%|███▏      | 16/50 [02:35<05:19,  9.41s/it]
# Bootstrapping:  34%|███▍      | 17/50 [02:45<05:14,  9.52s/it]
# Bootstrapping:  36%|███▌      | 18/50 [02:56<05:16,  9.88s/it]
# Bootstrapping:  38%|███▊      | 19/50 [03:05<05:01,  9.73s/it]
# Bootstrapping:  40%|████      | 20/50 [03:14<04:42,  9.42s/it]
# Bootstrapping:  42%|████▏     | 21/50 [03:23<04:26,  9.20s/it]
# Bootstrapping:  44%|████▍     | 22/50 [03:31<04:11,  8.99s/it]
# Bootstrapping:  46%|████▌     | 23/50 [03:40<04:00,  8.91s/it]
# Bootstrapping:  48%|████▊     | 24/50 [03:48<03:48,  8.80s/it]
# Bootstrapping:  50%|█████     | 25/50 [03:57<03:38,  8.73s/it]
# Bootstrapping:  52%|█████▏    | 26/50 [04:06<03:34,  8.92s/it]
# Bootstrapping:  54%|█████▍    | 27/50 [04:16<03:29,  9.10s/it]
# Bootstrapping:  56%|█████▌    | 28/50 [04:25<03:22,  9.20s/it]
# Bootstrapping:  58%|█████▊    | 29/50 [04:35<03:13,  9.22s/it]
# Bootstrapping:  60%|██████    | 30/50 [04:43<03:00,  9.05s/it]
# Bootstrapping:  62%|██████▏   | 31/50 [04:52<02:50,  8.95s/it]
# Bootstrapping:  64%|██████▍   | 32/50 [05:01<02:41,  8.99s/it]
# Bootstrapping:  66%|██████▌   | 33/50 [05:10<02:31,  8.93s/it]
# Bootstrapping:  68%|██████▊   | 34/50 [05:19<02:23,  8.94s/it]
# Bootstrapping:  70%|███████   | 35/50 [05:27<02:10,  8.70s/it]
# Bootstrapping:  72%|███████▏  | 36/50 [05:35<01:59,  8.50s/it]
# Bootstrapping:  74%|███████▍  | 37/50 [05:44<01:51,  8.57s/it]
# Bootstrapping:  76%|███████▌  | 38/50 [05:53<01:46,  8.91s/it]
# Bootstrapping:  78%|███████▊  | 39/50 [06:02<01:38,  8.94s/it]
# Bootstrapping:  80%|████████  | 40/50 [06:13<01:33,  9.33s/it]
# Bootstrapping:  82%|████████▏ | 41/50 [06:22<01:24,  9.43s/it]
# Bootstrapping:  84%|████████▍ | 42/50 [06:32<01:14,  9.35s/it]
# Bootstrapping:  86%|████████▌ | 43/50 [06:40<01:03,  9.14s/it]
# Bootstrapping:  88%|████████▊ | 44/50 [06:50<00:55,  9.28s/it]
# Bootstrapping:  90%|█████████ | 45/50 [07:01<00:49,  9.80s/it]
# Bootstrapping:  92%|█████████▏| 46/50 [07:11<00:39, 10.00s/it]
# Bootstrapping:  94%|█████████▍| 47/50 [07:21<00:29,  9.82s/it]
# Bootstrapping:  96%|█████████▌| 48/50 [07:29<00:18,  9.30s/it]
# Bootstrapping:  98%|█████████▊| 49/50 [07:37<00:08,  8.88s/it]
# Bootstrapping: 100%|██████████| 50/50 [07:45<00:00,  9.31s/it]

# %%
import json
json.dump([{'depth-10-incomplete': i['complete-pool-depth-all']} for i in ret], open('beir-evaluation-data/beir-bootstrapping-results.jsonl', 'w'))

# %%
import json
tmp = json.load(open('beir-evaluation-data/beir-bootstrapping-results.jsonl', 'r'))

# %%
def predict_bs_most_likely(i):
    i = i['depth-10-incomplete']
    model = BootstrappingBySelectingMostLikelyDataPoint('bs-run-and-pool-dependent-1000-ndcg@10')
    ret = []
    
    for l in i:
        #print(type(l['ndcg@10']))
        t = model.predict([l['ndcg@10']])
        assert len(t) == 1
        
        ret += [t[0]]
    
    print('run-and-pool-based-bs-most-likely: ', i[0]['run_file'], ':', mean(ret))

def predict_bs_95_percent_quantile(i):
    i = i['depth-10-incomplete']
    model = FixedQuantileBootstrappingModel('x', 95)
    ret = []
    print(i[0]['run_file'])
    for l in i:
        #print(type(l['ndcg@10']))
        t = model.predict([l['ndcg@10']])
        assert len(t) == 1
        
        ret += [t[0]]
    
    print('run-and-pool-based-bs-95-percent: ', i[0]['run_file'], ':', mean(ret))

def predict_max_residual(i):
    i = i['depth-10-incomplete']
    ret = []
    print
    for l in i:
        ret += [l['MAX-NDCG@10']]
    
    print('Max-residual', (i[0]['run_file']), ':', mean(ret))

# %%
predict_bs_most_likely(tmp[3])
predict_bs_95_percent_quantile(tmp[3])
predict_max_residual(tmp[0])
# Out:
# run-and-pool-based-bs-most-likely:  beir-evaluation-data/runs/colbert-ranking-26-12-2022-run.txt : 0.7409517338949408
# beir-evaluation-data/runs/colbert-ranking-26-12-2022-run.txt
# run-and-pool-based-bs-95-percent:  beir-evaluation-data/runs/colbert-ranking-26-12-2022-run.txt : 0.7885473343788988
# Max-residual beir-evaluation-data/runs/colbert-ranking-26-12-2022-run.txt : 0.8258838045277852

# %%
predict_bs_most_likely(tmp[4])
predict_bs_95_percent_quantile(tmp[4])
predict_max_residual(tmp[1])
# Out:
# run-and-pool-based-bs-most-likely:  beir-evaluation-data/runs/ance-09-01-2023-run.txt : 0.7474231965765935
# beir-evaluation-data/runs/ance-09-01-2023-run.txt
# run-and-pool-based-bs-95-percent:  beir-evaluation-data/runs/ance-09-01-2023-run.txt : 0.8041515476389878
# Max-residual beir-evaluation-data/runs/ance-09-01-2023-run.txt : 0.8527441906345933

# %%
predict_bs_most_likely(tmp[5])
predict_bs_95_percent_quantile(tmp[5])
predict_max_residual(tmp[2])
# Out:
# run-and-pool-based-bs-most-likely:  beir-evaluation-data/runs/tas-b-09-01-2023-run.txt : 0.6333194443585958
# beir-evaluation-data/runs/tas-b-09-01-2023-run.txt
# run-and-pool-based-bs-95-percent:  beir-evaluation-data/runs/tas-b-09-01-2023-run.txt : 0.7285839535510149
# Max-residual beir-evaluation-data/runs/tas-b-09-01-2023-run.txt : 0.8705287615794982
